# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanakakani/Dhana_INFO5502_Spring2022/blob/master/Dhanalakshmi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
...

#Predication of bike rental count hourly or daily based on the environmental and seasonal settings.
#We need to know how many bikes are being rented hourly based on months and years
#The numwrical data should be collected with huge number of parameters like season,year,month,day etc..
#Data set can be collected using 5 StrOrBytesPath1.determining what data need to be collected
#set the time frame of data collections
#collect and analyse the data.
#we need 21.5kbps of data and can be saved as csv file and we can read it by uploading in colab


...

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

hour=pd.read_csv('hour.csv')
hour.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour['dteday']=pd.to_datetime(hour.dteday)
hour['date']=hour.dteday.dt.day

hour['months']=hour.dteday.dt.month

hour['years']=hour.dteday.dt.year

# %%
hour
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1 2011-01-01       1   0     1   0        0        6           0
# 1            2 2011-01-01       1   0     1   1        0        6           0
# 2            3 2011-01-01       1   0     1   2        0        6           0
# 3            4 2011-01-01       1   0     1   3        0        6           0
# 4            5 2011-01-01       1   0     1   4        0        6           0
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
# ...

# %%
sns.countplot(hour['date'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot('season','casual',data=hour)
